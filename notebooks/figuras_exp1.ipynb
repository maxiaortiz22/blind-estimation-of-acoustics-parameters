# %%
import pandas as pd

# %%
pd.read_pickle("../results/exp1/output.pkl")
# Out:
#                                                scores  \
# 0   [[0.04, 0.06, 0.08, 0.0, 0.46, 0.22, 0.06, 0.0...
# 1   [[0.0, 0.0, 0.08, 0.04, 0.02, 0.02, 0.1, 0.72,...
# 2   [[0.02, 0.02, 0.16, 0.06, 0.06, 0.02, 0.22, 0....
# 3   [[0.0, 0.04, 0.0, 0.02, 0.86, 0.08, 0.0, 0.0, ...
# 4   [[0.06, 0.0, 0.2, 0.22, 0.0, 0.0, 0.16, 0.02, ...
# 5   [[0.04, 0.04, 0.0, 0.0, 0.78, 0.04, 0.06, 0.0,...
# 6   [[0.0, 0.0, 0.04, 0.16, 0.0, 0.02, 0.1, 0.02, ...
# 7   [[0.04, 0.06, 0.0, 0.0, 0.76, 0.08, 0.06, 0.0,...
# 8   [[0.5, 0.02, 0.18, 0.1, 0.0, 0.02, 0.02, 0.12,...
# 9   [[0.02, 0.04, 0.02, 0.0, 0.74, 0.04, 0.02, 0.1...
# 10  [[0.03, 0.11, 0.07, 0.02, 0.46, 0.12, 0.06, 0....
# 11  [[0.0, 0.01, 0.09, 0.0, 0.03, 0.03, 0.07, 0.71...
# 12  [[0.08, 0.03, 0.13, 0.08, 0.05, 0.03, 0.21, 0....
# 13  [[0.01, 0.04, 0.01, 0.01, 0.75, 0.05, 0.06, 0....
# 14  [[0.01, 0.0, 0.22, 0.12, 0.0, 0.0, 0.19, 0.01,...
# 15  [[0.0, 0.04, 0.01, 0.01, 0.82, 0.07, 0.03, 0.0...
# ...
